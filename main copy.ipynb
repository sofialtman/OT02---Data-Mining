# %%
import pandas as pd
import numpy as np
from typing import Optional, List, Callable, Any, Union, Dict
from itertools import product
from statistics import mean
from pathlib import Path
import gzip
import os

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ### Read datasets
# Use the gzip function is files ar gzipped

# %%
def read_ds_gzip(path: Optional[Path]=None, ds: str = "TRAIN") -> pd.DataFrame:
    """Args:
        path (Optional[Path], optional): the path to read the dataset file. Defaults to /kaggle/input/the-insa-starcraft-2-player-prediction-challenge/{ds}.CSV.gz.
        ds (str, optional): the part to read (TRAIN or TEST), to use when path is None. Defaults to "TRAIN".

    Returns:
        pd.DataFrame:
    """
    with gzip.open(f'/kaggle/input/the-insa-starcraft-2-player-prediction-challenge/{ds}.CSV.gz' if path is None else path) as f:
        max_actions = max(( len( str(c).split(",")) for c in f.readlines() ))
        f.seek(0)
        _names = ["battleneturl", "played_race"] if "TRAIN" in ds else ["played_race"]
        _names.extend(range(max_actions - len(_names)))
        return pd.read_csv(f, names=_names, dtype= str)

def read_ds(path: Optional[Path]=None, ds: str = "TRAIN"):
    """Args:
        path (Optional[Path], optional): the path to read the dataset file. Defaults to /kaggle/input/the-insa-starcraft-2-player-prediction-challenge/{ds}.CSV.gz.
        ds (str, optional): the part to read (TRAIN or TEST), to use when path is None. Defaults to "TRAIN".

    Returns:
        pd.DataFrame:
    """
    with open(f'/kaggle/input/train-sc2-keystrokes/{ds}.CSV' if path is None else path) as f:
        max_actions = max(( len( str(c).split(",")) for c in f.readlines() ))
        f.seek(0)
        _names = ["battleneturl", "played_race"] if "TRAIN" in ds else ["played_race"]
        _names.extend(range(max_actions - len(_names)))
        return pd.read_csv(f, names=_names, dtype= str)

# %%
features_train = read_ds(Path(os.path.abspath('')) / "data/TRAIN.CSV") # Replace with correct path 
# features_test = read_ds("TEST")
features_train.shape #, features_test.shape
# Out:
# (3052, 10539)

# %%
features_train
# Out:
#                                            battleneturl played_race     0  \
# 0     http://eu.battle.net/sc2/en/profile/4234852/1/...     Protoss  Base
# 1     http://eu.battle.net/sc2/en/profile/3074362/1/...     Protoss     s
# 2     http://eu.battle.net/sc2/en/profile/4234852/1/...     Protoss  Base
# 3     http://eu.battle.net/sc2/en/profile/3074362/1/...     Protoss  Base
# 4     http://eu.battle.net/sc2/en/profile/4234852/1/...     Protoss  Base
# ...                                                 ...         ...   ...
# 3047     http://xx.battle.net/sc2/en/profile/405/1/MMA/      Terran     s
# 3048  http://xx.battle.net/sc2/en/profile/410/1/STBo...      Terran     s
# 3049     http://xx.battle.net/sc2/en/profile/405/1/MMA/      Terran     s
# 3050  http://xx.battle.net/sc2/en/profile/410/1/STBo...      Terran     s
# 3051     http://xx.battle.net/sc2/en/profile/405/1/MMA/      Terran     s
#
#          1         2         3         4         5         6         7  ...  \
# 0        s         s         s         s         s        t5      Base  ...
# 1     Base         s         s      Base         s         s      Base  ...
# 2        s         s         s      Base         s  hotkey30  hotkey00  ...
# 3        s         s      Base         s         s         s        t5  ...
# 4        s         s         s      Base         s  hotkey30  hotkey00  ...
# ...    ...       ...       ...       ...       ...       ...       ...  ...
# 3047     s         s         s         s  hotkey10  hotkey20  hotkey30  ...
# 3048     s  hotkey10         s  hotkey20         s         s  hotkey12  ...
# 3049     s         s  hotkey10  hotkey20  hotkey30  hotkey40  hotkey50  ...
# 3050     s  hotkey10         s  hotkey20         s         s  hotkey12  ...
# 3051     s         s  hotkey10  hotkey20  hotkey30  hotkey40  hotkey50  ...
#
#      10527 10528 10529 10530 10531 10532 10533 10534 10535 10536
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 3047   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3048   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3049   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3050   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3051   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [3052 rows x 10539 columns]

# %%
features_train.head(20)
# Out:
#                                          battleneturl played_race     0  \
# 0   http://eu.battle.net/sc2/en/profile/4234852/1/...     Protoss  Base
# 1   http://eu.battle.net/sc2/en/profile/3074362/1/...     Protoss     s
# 2   http://eu.battle.net/sc2/en/profile/4234852/1/...     Protoss  Base
# 3   http://eu.battle.net/sc2/en/profile/3074362/1/...     Protoss  Base
# 4   http://eu.battle.net/sc2/en/profile/4234852/1/...     Protoss  Base
# 5   http://eu.battle.net/sc2/en/profile/3074362/1/...     Protoss     s
# 6   http://eu.battle.net/sc2/en/profile/4234852/1/...     Protoss  Base
# 7   http://eu.battle.net/sc2/en/profile/3074362/1/...     Protoss  Base
# 8   http://eu.battle.net/sc2/en/profile/3401218/1/...     Protoss  Base
# 9   http://eu.battle.net/sc2/en/profile/2896854/1/...      Terran     s
# 10  http://eu.battle.net/sc2/en/profile/3401218/1/...     Protoss  Base
# 11  http://eu.battle.net/sc2/en/profile/2896854/1/...      Terran     s
# 12  http://eu.battle.net/sc2/en/profile/3401218/1/...     Protoss  Base
# 13  http://eu.battle.net/sc2/en/profile/2896854/1/...      Terran     s
# 14  http://eu.battle.net/sc2/en/profile/3538115/1/...        Zerg  Base
# 15  http://eu.battle.net/sc2/en/profile/250458/1/V...        Zerg  Base
# 16  http://eu.battle.net/sc2/en/profile/3538115/1/...        Zerg     s
# 17  http://eu.battle.net/sc2/en/profile/250458/1/V...        Zerg  Base
# 18  http://eu.battle.net/sc2/en/profile/3538115/1/...        Zerg     s
# 19  http://eu.battle.net/sc2/en/profile/250458/1/V...        Zerg  Base
#
#            1         2         3         4         5         6         7  ...  \
# 0          s         s         s         s         s        t5      Base  ...
# 1       Base         s         s      Base         s         s      Base  ...
# 2          s         s         s      Base         s  hotkey30  hotkey00  ...
# 3          s         s      Base         s         s         s        t5  ...
# 4          s         s         s      Base         s  hotkey30  hotkey00  ...
# 5       Base         s         s      Base         s  hotkey30         s  ...
# 6          s         s         s      Base         s  hotkey30  hotkey00  ...
# 7          s         s      Base         s         s      Base         s  ...
# 8          s  hotkey40        t5       t10         s  hotkey20  hotkey42  ...
# 9   hotkey30  hotkey00        t5         s  hotkey32         s  hotkey32  ...
# 10         s  hotkey40        t5         s  hotkey42         s  hotkey42  ...
# 11  hotkey30  hotkey00        t5         s  hotkey32         s  hotkey32  ...
# 12         s  hotkey40        t5         s  hotkey42       t10         s  ...
# 13  hotkey30  hotkey00        t5         s  hotkey32         s  hotkey32  ...
# 14         s         s         s  hotkey10      Base         s  hotkey60  ...
# 15         s         s         s         s  hotkey20      Base         s  ...
# 16         s  hotkey10      Base         s  hotkey60         s  hotkey00  ...
# 17         s         s         s  hotkey20      Base         s  hotkey40  ...
# 18         s         s  hotkey10         s  hotkey60         s  hotkey00  ...
# 19         s         s         s  hotkey20      Base         s  hotkey40  ...
#
#    10527 10528 10529 10530 10531 10532 10533 10534 10535 10536
# 0    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 16   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 17   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 18   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 19   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [20 rows x 10539 columns]

# %%
features_train.columns
# Out:
# Index(['battleneturl',  'played_race',              0,              1,
#                     2,              3,              4,              5,
#                     6,              7,
#        ...
#                 10527,          10528,          10529,          10530,
#                 10531,          10532,          10533,          10534,
#                 10535,          10536],
#       dtype='object', length=10539)

# %%
features_train.describe()
# Out:
#                                              battleneturl played_race     0  \
# count                                                3052        3052  3044
# unique                                                200           3     4
# top     http://kr.battle.net/sc2/en/profile/2348639/1/...     Protoss     s
# freq                                                   58        1210  1839
#
#            1     2     3     4     5     6     7  ...     10527     10528  \
# count   3044  3044  3044  3044  3044  3043  3042  ...         1         1
# unique    10    17    22    28    27    29    32  ...         1         1
# top        s     s     s     s     s     s     s  ...  hotkey22  hotkey12
# freq    2757  2569  1770  1610  1174  1046   888  ...         1         1
#
#            10529     10530     10531     10532     10533     10534     10535  \
# count          1         1         1         1         1         1         1
# unique         1         1         1         1         1         1         1
# top     hotkey22  hotkey12  hotkey22  hotkey12  hotkey22  hotkey42  hotkey12
# freq           1         1         1         1         1         1         1
#
#         10536
# count       1
# unique      1
# top     t5770
# freq        1
#
# [4 rows x 10539 columns]

# %% [markdown]
# We have 200 different players, which in total played a sum of 3052 races.
# There are three kind of races.
# The  line without nan values represents the line with the longest race (largest number of actions, therefore, of columns)

# %%
features_train[10527].unique()
# Out:
# array([nan, 'hotkey22'], dtype=object)

# %%
features_train.isna().sum()
# Out:
# battleneturl       0
# played_race        0
# 0                  8
# 1                  8
# 2                  8
#                 ...
# 10532           3051
# 10533           3051
# 10534           3051
# 10535           3051
# 10536           3051
# Length: 10539, dtype: int64

# %% [markdown]
# In the first action column, we already  have 8 null values, indicating 8 races with no actions.
# Possibly interesting graph: distribution of the number of actions per race and distribution of the  the number of actions per race per user.
# Careful:  If we remove all the rows of a player because he always plays a low number of actions, we lose information because we wont be able to identify this player later.

# %% [markdown]
# #### Removing outliers
# YOUR IDEAS / APPROACHES HERE.

# %%
#TODO
# YOUR CODE HERE
df_cleaned = features_train.dropna(subset=[0])

df_cleaned.shape
# Out:
# (3044, 10540)

# %% [markdown]
# ### Handling string
# The race_played column can only take three values; instead of converting it to categorical as we did with our dependent variable, we will instead convert it to dummy variables: we one-hot encode each race. It will not add many columns to our dataframe (only three) but will allow the decision trees to split much faster on the race (on only one binary split).

# %%
def get_dummies(df: pd.DataFrame):
    """Converts textual columns to one-hot encoded vectors (one column per possible value)"""
    df = pd.get_dummies(df, columns=["played_race"])
    return df

# %% [markdown]
# ### Dependent Variable
# Our dependent variable is a categorical string; we can convert it to categories codes (number) with pd.Categorical
#
# pd.Categorical doesn't directly modify the battleneturl to a number, instead it adds a cat.codes attribute to it. We can create a little function to convert the dependent variable from string to its category ID:

# %%
def to_categories(df: pd.DataFrame, col: str="battleneturl") -> None:
    """Convert col of df to a categorical column"""
    df["battleneturl"] = pd.Categorical(df["battleneturl"])
    df[[col]] = df[[col]].apply(lambda x: x.cat.codes)

# %%
def preprocess(df: pd.DataFrame, min_: int, max_: int, is_train: bool=True, convert_race: bool=True, **kwargs):
    """Calls FeatureGetter on the dataframe, applying preprocessing steps before
    Args:
        df (pd.DataFrame)
        min_ (int)
        max_ (int)
        is_train (bool, optional): whether the current dataframe contains training data 
            (to preprocess dependent variable or not). Defaults to True.
        convert_race (bool, optional): whether to convert race attribute to dummies. Defaults to True.

    Returns:
        _type_: _description_
    """
    #df = create_features(df, min_, max_, **kwargs)
    if convert_race: 
        df = get_dummies(df)
    df.columns = df.columns.astype(str)
    if is_train:
        to_categories(df)
    return df

# %%
# %%time
cnt=0
processed_df = preprocess(df_cleaned, 0, features_train.shape[1]-3, drop=True, n_rows=3052, log=True) 
processed_df.head()
# Out:
# CPU times: user 679 ms, sys: 312 ms, total: 990 ms
# Wall time: 1.68 s
#    battleneturl     0     1  2     3     4  5         6         7     8  ...  \
# 0            53  Base     s  s     s     s  s        t5      Base     s  ...
# 1            29     s  Base  s     s  Base  s         s      Base     s  ...
# 2            53  Base     s  s     s  Base  s  hotkey30  hotkey00    t5  ...
# 3            29  Base     s  s  Base     s  s         s        t5  Base  ...
# 4            53  Base     s  s     s  Base  s  hotkey30  hotkey00    t5  ...
#
#   10531 10532 10533 10534 10535 10536 num_actions played_race_Protoss  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN        2563                True
# 1   NaN   NaN   NaN   NaN   NaN   NaN        2408                True
# 2   NaN   NaN   NaN   NaN   NaN   NaN        1550                True
# 3   NaN   NaN   NaN   NaN   NaN   NaN        1589                True
# 4   NaN   NaN   NaN   NaN   NaN   NaN         727                True
#
#   played_race_Terran played_race_Zerg
# 0              False            False
# 1              False            False
# 2              False            False
# 3              False            False
# 4              False            False
#
# [5 rows x 10542 columns]

# %% [markdown]
# ### Exploratory analysis

# %%
# Calculate number of actions for each row (excluding played_race)
features_train['num_actions'] = features_train.drop(columns=['battleneturl','played_race']).notna().sum(axis=1)

# Plot histogram of actions per race
plt.figure(figsize=(8, 5))
sns.histplot(data=features_train, x='num_actions',hue='played_race', kde=True, palette="viridis", multiple="stack")
plt.title("Distribution of Actions by Race", fontsize=14)
plt.xlabel("Number of Actions", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.show()

# %%
# Group by 'player' and count total actions
player_action_counts = features_train.groupby('battleneturl')['num_actions'].mean()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=player_action_counts.values, orient="v", color="skyblue", width=0.3, flierprops={"marker": "o", "color": "red", "markersize": 6})
plt.title("Distribution of Actions per Player", fontsize=14)
plt.ylabel("Number of Actions", fontsize=12)
plt.show()

# %% [markdown]
# Distribution of players among the three types of races

# %%
class CancelBatchException(Exception):
    """Used to cancel processing of a batch of data (when the keystroke sequence is fully read)"""
